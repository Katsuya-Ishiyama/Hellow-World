# %% [markdown]
# # GitHubにJupyter Notebookのipynbファイル送信テスト
#
# GitHub上でipynbがレンダリングされて表示されれば成功。

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas import DataFrame, Series
ts = Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()

# %%
ts.plot()

# %%
df = DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list('ABCD'))
df = df.cumsum()

# %%
plt.figure()
df.plot()
